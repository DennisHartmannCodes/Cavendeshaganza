# %%
# importing module
from pandas import *
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
 
# reading CSV file
data = read_csv("Cavendeshaganza - End-Deflection run 1 whacky.csv")
 
# converting column data to list
times = data['t(s)'].tolist()
times=times[:64]
del times[53]
Position = data['Position(cm)'].tolist()
Position=Position[:64]
del Position[53]
Error = data['Error in Position (cm)'].tolist()
Error=Error[:64]
del Error[53]
S21=np.mean(Position)
print(S21)
 
# printing list data
plt.scatter(times,Position, color='b')
plt.errorbar(times, Position, yerr=Error, ecolor='r', fmt="o", barsabove="True")
plt.title('End-Deflection Method')
plt.xlabel('Time (s)')
plt.ylabel('Position (cm)')

max1=Position.index(max(Position[5:]))
max2=Position.index(max(Position[22:]))
T1=(max2-max1)*30
print(T1)
# slope, s2, r_value, p_value, std_err = stats.linregress(times,Position)
# print(slope)
# print("The position 2 intercept is ",s2, "+/-",std_err)
# b=[s2] *63
# plt.plot(times,b)
# s2=s2/100
# plt.savefig('EndDeflectrun1.png')
# Out:
# 6.3126984126984125
# 600

# %%
# reading CSV file
data = read_csv("Cavendeshaganza - End-Deflection Run 2.csv")
 
# converting column data to list
times = data['t(s)'].tolist()
times=times[:83]
Position = data['Position(cm)'].tolist()
Position=Position[:83]
Error = data['Error in Position (cm)'].tolist()
Error=Error[:83]
S11=np.mean(Position)
print(S11)
 
# printing list data
plt.scatter(times,Position, color='b')
plt.errorbar(times, Position, yerr=Error, ecolor='r', fmt="o", barsabove="True")
plt.title('End-Deflection Method')
plt.xlabel('Time (s)')
plt.ylabel('Position (cm)')


min1=Position.index(min(Position[5:]))
min2=Position.index(min(Position[14:]))
T2=(min2-min1)*30
print(T2)
# d=0.05
# realb=0.047
# m1=1.5

# slope, s1, r_value, p_value, std_err = stats.linregress(times,Position)

# print("The position 1 intercept is ",s1, "+/-",std_err)
# b=[s1] *83
# plt.plot(times,b)

# plt.savefig('EndDeflectrun2.png')
# Out:
# -2.191566265060241
# 630

# %%
# reading CSV file
data = read_csv("Cavendeshaganza - End-Deflection Run 3 (1).csv")
#print(data)
 
# converting column data to list
times = data['t(s)'].tolist()
times=times[11:72]
Position = data['Position(cm)'].tolist()
Position=Position[11:72]
Error = data['Error in Position (cm)'].tolist()
Error=Error[11:72]
S22=np.mean(Position)
print(S22)
 
#printing list data
plt.scatter(times,Position, color='b')
plt.errorbar(times, Position, yerr=Error, ecolor='r', fmt="o", barsabove="True")
plt.title('End-Deflection Method')
plt.xlabel('Time (s)')
plt.ylabel('Position (cm)')

min1=Position.index(min(Position[5:]))
min2=Position.index(min(Position[14:]))
T3=(min2-min1)*30
print(T3)
# Out:
# 7.634426229508197
# 660

# %%
data = read_csv("Cavendeshaganza - End-Deflection Run 4 (1).csv")
 
# converting column data to list
times = data['t(s)'].tolist()
times=times[20:82]
Position = data['Position(cm)'].tolist()
Position=Position[20:82]
Error = data['Error in Position (cm)'].tolist()
Error=Error[20:82]
S12=np.mean(Position)
print(S12)

plt.scatter(times,Position, color='b')
plt.errorbar(times, Position, yerr=Error, ecolor='r', fmt="o", barsabove="True")
plt.title('End-Deflection Method')
plt.xlabel('Time (s)')
plt.ylabel('Position (cm)')

min1=Position.index(min(Position[5:]))
min2=Position.index(min(Position[14:]))
T4=(min2-min1)*30
print(T4)
# Out:
# -0.2612903225806451
# 630

# %%
data = read_csv("Cavendeshaganza - End-Deflection Run 5.csv")
 
# converting column data to list
times = data['t(s)'].tolist()
times=times[11:98]
Position = data['Position(cm)'].tolist()
Position=Position[11:98]
Error = data['Error in Position (cm)'].tolist()
Error=Error[11:98]
S23=np.mean(Position)
print(S23)

plt.scatter(times,Position, color='b')
plt.errorbar(times, Position, yerr=Error, ecolor='r', fmt="o", barsabove="True")
plt.title('End-Deflection Method')
plt.xlabel('Time (s)')
plt.ylabel('Position (cm)')

min1=Position.index(min(Position[5:]))
min2=Position.index(min(Position[14:]))
T5=(min2-min1)*30
print(T5)
# Out:
# 7.480459770114943
# 630

# %%
# data = read_csv("Cavendeshaganza - End-Deflection Run 6.csv")
 
# # converting column data to list
# times = data['t(s)'].tolist()
# times=times[10:98]
# Position = data['Position(cm)'].tolist()
# Position=Position[10:98]
# Error = data['Error in Position (cm)'].tolist()
# Error=Error[10:98]
# S23=np.mean(Position)
# print(S23)

# plt.scatter(times,Position, color='b')
# plt.errorbar(times, Position, yerr=Error, ecolor='r', fmt="o", barsabove="True")
# plt.title('End-Deflection Method')
# plt.xlabel('Time (s)')
# plt.ylabel('Position (cm)')

# %%
data = read_csv("Cavendeshaganza - End-Deflection Run 7.csv")
 
# converting column data to list
times = data['t(s)'].tolist()
times=times[11:95]
Position = data['Position(cm)'].tolist()
Position=Position[11:95]
Error = data['Error in Position (cm)'].tolist()
Error=Error[11:95]
S13=np.mean(Position)
print(S13)

plt.scatter(times,Position, color='b')
plt.errorbar(times, Position, yerr=Error, ecolor='r', fmt="o", barsabove="True")
plt.title('End-Deflection Method')
plt.xlabel('Time (s)')
plt.ylabel('Position (cm)')

max1=Position.index(max(Position[5:]))
max2=Position.index(max(Position[14:]))
T6=(max2-max1)*30
print(T6)
# Out:
# -2.223809523809524
# 630

# %%
data = read_csv("Cavendeshaganza - No balls.csv")
 
# converting column data to list
times = data['t(s)'].tolist()
times=times[9:72]
Position = data['Position(cm)'].tolist()
Position=Position[9:72]
Error = data['Error in Position (cm)'].tolist()
Error=Error[9:72]
L1=(np.mean(Position))/100
print(L1)
L1error=(np.std(Position)/len(Position))/100
print(L1error)

plt.scatter(times,Position, color='b')
plt.errorbar(times, Position, yerr=Error, ecolor='r', fmt="o", barsabove="True")
plt.title('End-Deflection Method')
plt.xlabel('Time (s)')
plt.ylabel('Position (cm)')
# Out:
# 0.02714285714285715
# 0.00024229696670136734
# Text(0, 0.5, 'Position (cm)')

# %%
S1s=[S11,S12,S13]
S2s=[S21,S22,S23]
S1=(np.mean(S1s))/100
S1error=(np.std(S1s)/(3**.5))/100
S2=(np.mean(S2s))/100
S2error=(np.std(S2s)/(3**.5))/100
Ts=[T1,T2,T3,T4,T5,T6]
T=(np.mean(Ts))
Terror=(np.std(Ts)/(6**.5))
print('S1 is ',S1, '+/-', S1error)
print('S2 is ',S2, '+/-', S2error)
print('T is ',T, '+/-', Terror)

d=0.05
m1=1.5
b=0.047
L0=2.33
L0error=0.01
# Out:
# S1 is  -0.015588887038168036 +/- 0.005297968323745994
# S2 is  0.07142528137440518 +/- 0.003407147541741208
# T is  630.0 +/- 7.071067811865476

# %%
G=((np.pi**2)*((b)**2)*d*(S2-S1)*L0)/(m1*(T**2)*((L0**2)+(L1**2)))
print(G)
# Out:
# 6.837041692233595e-11
