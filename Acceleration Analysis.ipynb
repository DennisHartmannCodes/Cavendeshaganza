# %%
# importing module
from pandas import *
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import re

# %%
# reading CSV file
data = read_csv("Cavendeshaganza - Accelration run 1.csv")
 
# converting column data to list
timesquared = data['t^2(s^2)'].tolist()
timesquared=timesquared[6:32]
Position = data['Position (cm)+1.25'].tolist()
Position=Position[6:32]
Error = data['Error in Position(cm)'].tolist()
Error=Error[6:32]
 
# printing list data
plt.scatter(timesquared,Position, color='b')
plt.errorbar(timesquared, Position, yerr=Error, ecolor='r', fmt="o", barsabove="True")
plt.title('Acceleration Method')
plt.xlabel('Time^2 (s^2)')
plt.ylabel('Position (cm)')

for i in range(len(timesquared)):
    timesquared[i] = re.sub(",", "", timesquared[i])
    timesquared[i]=int(timesquared[i])

slope1, intercept, r_value, p_value, std_err = stats.linregress(timesquared,Position)

print(slope1)
# Out:
# 0.0001246208013077443

# %%
# reading CSV file
data = read_csv("Cavendeshaganza - Acceleration Run 2.csv")
 
# converting column data to list
timesquared = data['t^2(s^2)'].tolist()
timesquared=timesquared[1:25]
Position = data['Position (cm)+1.25'].tolist()
Position=Position[1:25]
Error = data['Error in Position(cm)'].tolist()
Error=Error[1:25]
 
# printing list data
plt.scatter(timesquared,Position, color='b')
plt.errorbar(timesquared, Position, yerr=Error, ecolor='r', fmt="o", barsabove="True")
#plt.xticks(np.arange(0, 20, step=3))  # Set label locations.
#plt.xlim(2,19)
plt.title('Acceleration Method')
plt.xlabel('Time^2 (s^2)')
plt.ylabel('Position (cm)')

for i in range(len(timesquared)):
    timesquared[i] = re.sub(",", "", timesquared[i])
    timesquared[i]=int(timesquared[i])

slope2, intercept, r_value, p_value, std_err = stats.linregress(timesquared,Position)

print(slope2)
# Out:
# -0.0002804478955857349

# %%
# reading CSV file
data = read_csv("Cavendeshaganza - Acceleration Run 3 (2).csv")
 
# converting column data to list
timesquared = data['t^2(s^2)'].tolist()
timesquared=timesquared[4:30]
Position = data['Position (cm)+1.25'].tolist()
Position=Position[4:30]
Error = data['Error in Position(cm)'].tolist()
Error=Error[4:30]
 
# printing list data
plt.scatter(timesquared,Position, color='b')
plt.errorbar(timesquared, Position, yerr=Error, ecolor='r', fmt="o", barsabove="True")
#plt.xticks(np.arange(0, 20, step=3))  # Set label locations.
#plt.xlim(2,19)
plt.title('Acceleration Method')
plt.xlabel('Time^2 (s^2)')
plt.ylabel('Position (cm)')

for i in range(len(timesquared)):
    timesquared[i] = re.sub(",", "", timesquared[i])
    timesquared[i]=int(timesquared[i])

slope3, intercept, r_value, p_value, std_err = stats.linregress(timesquared,Position)

print(slope3)
# Out:
# 0.0001469422093165258

# %%
# reading CSV file
data = read_csv("Cavendeshaganza - Acceleration Run 4 (2).csv")
 
# converting column data to list
timesquared = data['t^2(s^2)'].tolist()
timesquared=timesquared[3:26]
Position = data['Position (cm)+1.25'].tolist()
Position=Position[3:26]
Error = data['Error in Position(cm)'].tolist()
Error=Error[3:26]
 
# printing list data
plt.scatter(timesquared,Position, color='b')
plt.errorbar(timesquared, Position, yerr=Error, ecolor='r', fmt="o", barsabove="True")
plt.title('Acceleration Method')
plt.xlabel('Time^2 (s^2)')
plt.ylabel('Position (cm)')

for i in range(len(timesquared)):
    timesquared[i] = re.sub(",", "", timesquared[i])
    timesquared[i]=int(timesquared[i])

slope4, intercept, r_value, p_value, std_err = stats.linregress(timesquared,Position)

print(slope4)
# Out:
# -0.00015595756900104726

# %%
# reading CSV file
data = read_csv("Cavendeshaganza - Acceleration Run 5 (2).csv")
 
# converting column data to list
timesquared = data['t^2(s^2)'].tolist()
timesquared=timesquared[3:29]
Position = data['Position (cm)+1.25'].tolist()
Position=Position[3:29]
Error = data['Error in Position(cm)'].tolist()
Error=Error[3:29]
 
# printing list data
plt.scatter(timesquared,Position, color='b')
plt.errorbar(timesquared, Position, yerr=Error, ecolor='r', fmt="o", barsabove="True")
plt.title('Acceleration Method')
plt.xlabel('Time^2 (s^2)')
plt.ylabel('Position (cm)')

for i in range(len(timesquared)):
    timesquared[i] = re.sub(",", "", timesquared[i])
    timesquared[i]=int(timesquared[i])

slope5, intercept, r_value, p_value, std_err = stats.linregress(timesquared,Position)

print(slope5)
# Out:
# 0.00017412579687385812

# %%
# reading CSV file
data = read_csv("Cavendeshaganza - Acceleration Run 6.csv")
 
# converting column data to list
timesquared = data['t^2(s^2)'].tolist()
timesquared=timesquared[2:29]
Position = data['Position (cm)+1.25'].tolist()
Position=Position[2:29]
Error = data['Error in Position(cm)'].tolist()
Error=Error[2:29]
 
# printing list data
plt.scatter(timesquared,Position, color='b')
plt.errorbar(timesquared, Position, yerr=Error, ecolor='r', fmt="o", barsabove="True")
plt.title('Acceleration Method')
plt.xlabel('Time^2 (s^2)')
plt.ylabel('Position (cm)')

for i in range(len(timesquared)):
    timesquared[i] = re.sub(",", "", timesquared[i])
    timesquared[i]=int(timesquared[i])

slope6, intercept, r_value, p_value, std_err = stats.linregress(timesquared,Position)

print(slope6)
# Out:
# 0.0001528787947065627

# %%
# reading CSV file
data = read_csv("Cavendeshaganza - Acceleration Run 7.csv")
 
# converting column data to list
timesquared = data['t^2(s^2)'].tolist()
timesquared=timesquared[8:31]
Position = data['Position (cm)+1.25'].tolist()
Position=Position[8:31]
Error = data['Error in Position(cm)'].tolist()
Error=Error[8:31]
 
# printing list data
plt.scatter(timesquared,Position, color='b')
plt.errorbar(timesquared, Position, yerr=Error, ecolor='r', fmt="o", barsabove="True")
plt.title('Acceleration Method')
plt.xlabel('Time^2 (s^2)')
plt.ylabel('Position (cm)')
plt.savefig('Accelrun2.png')

for i in range(len(timesquared)):
    timesquared[i] = re.sub(",", "", timesquared[i])
    timesquared[i]=int(timesquared[i])

slope7, intercept, r_value, p_value, std_err = stats.linregress(timesquared,Position)

print(slope7)
# Out:
# -0.00021175241256377156

# %%
slopes=[abs(slope1),abs(slope2),abs(slope3),abs(slope4),abs(slope5),abs(slope6),abs(slope7)]
slope=np.mean(slopes)/100
slopeerror=(np.std(slopes)/(7**0.5))/100
print('The slope is ', slope, ' +/- ', slopeerror)
# Out:
# The slope is  1.7810363990789206e-06  +/-  1.8395096873326448e-07

# %%
data = read_csv("Cavendeshaganza - No balls.csv")
 
# converting column data to list
times = data['t(s)'].tolist()
times=times[9:72]
Position = data['Position(cm)'].tolist()
Position=Position[9:72]
Error = data['Error in Position (cm)'].tolist()
Error=Error[9:72]
L1=(np.mean(Position))/100
print(L1)
L1error=(np.std(Position)/len(Position))/100
print(L1error)
# Out:
# 0.02714285714285715
# 0.00024229696670136734

# %%
d=0.05
m1=1.5
b=0.047
L0=2.33
L0error=0.01

# %%
G=(1/2)*((b**2)*d*L0)/(m1*((L0**2)+(L1**2)))*slope
print(G)
# Out:
# 2.8138594909407153e-11
